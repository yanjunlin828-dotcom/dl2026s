# %% [markdown]
# # 作业1：问卷+环境配置

# %% [markdown]
# ## 0. 说明

# %% [markdown]
# ### 0.1 关于 Jupyter Notebook

# %% [markdown]
# Jupyter Notebook 是一种可编程的文档类型，类似于 R Markdown。Jupyter Notebook 文档以一个个单元格组成，每个单元格可以是 Markdown 或者 Python 代码：前者通常用来写文字说明，后者用来运行代码。比如你双击第一行的标题，就会看到标题的 Markdown 代码（以 `#` 符号开头），再按 `Ctrl+Enter`，就会显示 Markdown 渲染的结果。

# %% [markdown]
# 而对于代码单元格， `Ctrl+Enter` 会执行单元格内的代码，例如用鼠标点击下面的单元格然后按键后会出现形如 `Out[x]` 的输出结果。

# %%
import math

math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# 我们的作业中既有需要说明的文字，又有需要编写的程序，前者用 Markdown 单元格，后者用代码单元格。单元格的类型可以在上方的下拉菜单中选择，也可以通过快捷键实现（通过菜单 Cell => Cell Type 查看）。

# %% [markdown]
# ### 0.2 关于 Markdown

# %% [markdown]
# Markdown 是常用的文档格式化语法，如果有不熟悉的，可以参考[这里](https://www.jianshu.com/p/335db5716248)的教程。需要说明的是 Jupyter Notebook 里可以插入数学公式，例如 $f(x)=\frac{1}{\sqrt{2\pi}}e^{-x^2/2}$。双击这个单元格来查看源代码。

# %% [markdown]
# ## 1. 练习

# %% [markdown]
# 1.1 请在下方插入一个 Markdown 单元格，输入一段文字，里面需包括斜体、粗体和列表格式。然后插入一张图片，图片地址使用相对路径，图片文件与 Notebook 一同上传。

# %% [markdown]
# 文字，*斜体*，**粗体**
#  * a
#  * b
#  * c
# ![图](1.png)

# %% [markdown]
# 1.2 选取三个包含数学公式的定理，用 Markdown 格式在下方插入。

# %% [markdown]
# ### 1. 勾股定理
# 在直角三角形中，两直角边的平方和等于斜边的平方：
#
# $$a^2 + b^2 = c^2$$
#
# ---
#
# ### 2. 欧拉公式
#
# $$e^{i\pi} + 1 = 0$$
#
# ---
#
# ### 3. 二次方程求根公式
# 对于方程 $ax^2 + bx + c = 0$，其解为：
#
# $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$

# %% [markdown]
# ## 2. 问卷

# %% [markdown]
# 思考并回答以下问题：

# %% [markdown]
# - 你现在对深度学习有多少了解？

# %% [markdown]
# 对一些基础的算法想法有所了解但是不深入，同时对与其具体的应用和实现不清楚

# %% [markdown]
# - 你预期今后的工作/研究与深度学习关联大吗？

# %% [markdown]
# 可能会比较大，之后想做量化金融，需要使用深度学习挖因子之类的

# %% [markdown]
# - 你喜欢/**不**喜欢的上课方式是怎样的？你想从这门课中学到什么？

# %% [markdown]
# 喜欢能有逻辑的把一个知识点逐步讲透，在第二节课开始的时候会复习之前的内容，不喜欢讲课用很多专业术语，讲课晦涩，讲课发散没有逻辑。除此之外还有白板上的字实在是看不清有点太小了

# %% [markdown]
# - 你有哪些喜欢的获取知识的渠道（例如B站，知乎，技术博客，公众号等）？如果有请推荐一些，**具体到账号或网址**，不需要与本课程相关。回答仅作汇总使用，不会关联你的个人信息。

# %% [markdown]
# 主要还是B站看各种课程吧，但是更多还是问ai

# %% [markdown]
# - 你平时使用的 AI 工具有哪些？它们各自的使用场景是怎样的？

# %% [markdown]
# claude做平时的问题解答任务以及编程，gemini做多模态任务，学术相关的查询用秘塔，不方便打字的时候用豆包说话

# %% [markdown]
# - 你觉得 AI 的发展对自己未来可能有哪些影响？是正向的还是负向的？

# %% [markdown]
# 大概率还是正向的吧，可以让我更加容易的学习以及完成各种事项和任务，但是可能也会让我自己做编程任务的能力下降。

# %% [markdown]
# ## 2. 安装 PyTorch

# %% [markdown]
# 请参照课程文档《PyTorch安装》的提示配置好 PyTorch 环境。如果你的电脑具备 Nvidia 显卡，**优先尝试安装 GPU 版本**。用如下的代码验证 Conda 和 PyTorch 安装是否成功：

# %%
# !conda info
# Out:
#      active environment : dl2026s
#     active env location : C:\Users\lengyanjun\anaconda3\envs\dl2026s
#             shell level : 2
#        user config file : C:\Users\lengyanjun\.condarc
#  populated config files : C:\Users\lengyanjun\anaconda3\.condarc
#                           C:\Users\lengyanjun\.condarc
#           conda version : 24.11.3
#     conda-build version : 24.9.0
#          python version : 3.12.7.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=skylake
#                           __conda=24.11.3=0
#                           __win=0=0
#        base environment : C:\Users\lengyanjun\anaconda3  (writable)
#       conda av data dir : C:\Users\lengyanjun\anaconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
#                           https://repo.anaconda.com/pkgs/msys2/noarch
#           package cache : C:\Users\lengyanjun\anaconda3\pkgs
#                           C:\Users\lengyanjun\.conda\pkgs
#                           C:\Users\lengyanjun\AppData\Local\conda\conda\pkgs
#        envs directories : C:\Users\lengyanjun\anaconda3\envs
#                           C:\Users\lengyanjun\.conda\envs
#                           C:\Users\lengyanjun\AppData\Local\conda\conda\envs
#                platform : win-64
#              user-agent : conda/24.11.3 requests/2.32.3 CPython/3.12.7 Windows/11 Windows/10.0.26200 solver/libmamba conda-libmamba-solver/24.9.0 libmambapy/1.5.8 aau/0.4.4 c/dsNg3uWTmtR3DyawKQuyaQ s/nEO3uktY-EpcmIIDyAywEw e/V6CvGfcbsjM3C7AU-ip7bg
#           administrator : False
#              netrc file : None
#            offline mode : False

# %%
import torch
torch.manual_seed(123)
torch.randn(5, 3)
# Out:
# tensor([[-0.1115,  0.1204, -0.3696],
#         [-0.2404, -1.1969,  0.2093],
#         [-0.9724, -0.7550,  0.3239],
#         [-0.1085,  0.2103, -0.3908],
#         [ 0.2350,  0.6653,  0.3528]])

# %%
torch.cuda.is_available()
# Out:
# False
